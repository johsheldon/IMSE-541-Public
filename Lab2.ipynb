# %% [markdown]
# <a href="https://colab.research.google.com/github/johsheldon/IMSE-541-Public/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import statistics
import numpy as np
import scipy.stats as stats
import pandas as pd
from statsmodels.stats import weightstats as stests
import matplotlib.pyplot as plt
from google.colab import files

#Question 1
data1 = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
data2 = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-58024174-a599-4040-aa76-fcd7c10bd7c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58024174-a599-4040-aa76-fcd7c10bd7c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data1=pd.read_csv('Batch 1.csv')
data2=pd.read_csv('Batch 2.csv')

# %%
data1.describe()
# Out:
#          Batch 1
# count  50.000000
# mean    1.003360
# std     0.007714
# min     0.985000
# 25%     0.999000
# 50%     1.001000
# 75%     1.009000
# max     1.025000

# %%
data2.describe()
# Out:
#          Batch 2
# count  50.000000
# mean    1.003660
# std     0.007227
# min     0.990000
# 25%     1.000000
# 50%     1.005000
# 75%     1.006750
# max     1.019000

# %%
data1=pd.read_csv('Batch 1.csv')
data1.plot.hist(grid=True, bins=10, rwidth=0.9,
                   color='#607c8e')
plt.title('Data Histogram')
plt.xlabel('ranked data')
plt.ylabel('Counts')
plt.grid(axis='y', alpha=0.75)

# %%
data1=pd.read_csv('Batch 1.csv')
data1.plot.hist(grid=True, bins=10, rwidth=0.9,
                   color='#607c8e')
plt.title('Data Histogram')
plt.xlabel('ranked data')
plt.ylabel('Counts')
plt.grid(axis='y', alpha=0.75)

# %%
#The data looks very similar.  Without running any hypothesis tests, I am guessing the data is too similar to reject the null hypothesis.

# %%
#Question 2

# %%
data1=pd.read_csv('Batch 1.csv')
data2=pd.read_csv('Batch 2.csv')

# %%
pd.read_csv("BUSHING DIAMETER 2 BATCHES.csv")
def f_test(x,y):
  x=np.array(x)
  y=np.array(y)
  f=np.var(x,ddof=1)/np.var(y, ddof=1) # cal F test statistic
  dfn=x.size-1
  dfd=y.size-1
  p=1-stats.f.cdf(f,dfn, dfd) #find p-value of F test statistics
  return f, p
  
f_test(data1, data2)
# Out:
# (1.1392199163691206, 0.32501448085544293)

# %%
#two sample t-test 1: assume the variance is the same (default)
stats.ttest_ind(data1, data2, equal_var=True)
# Out:
# Ttest_indResult(statistic=array([-0.20069321]), pvalue=array([0.84135439]))

# %%
#The P-Value is really high, higher than 0.05.  So we fail to reject the null hypothesis.  We can conclude that the data is not significantly different.

# %%
import math
import statistics
import numpy as np
import scipy.stats as stats
import pandas as pd
from statsmodels.stats import weightstats as stests
import matplotlib.pyplot as plt
from google.colab import files
metal=[13.3987, 13.3957, 13.3902, 13.4015, 13.4001, 13.3918, 13.3965, 13.3925, 13.3946, 13.4002]
fig = plt.figure(figsize= (10, 10))
ax = fig.add_subplot(111)

normality_plot, stat = stats.probplot(metal, plot= plt, rvalue= True)
ax.set_title("Probability plot of Metal Thickness", fontsize= 20)
ax.set

plt.show()
